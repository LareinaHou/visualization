# %%
#basic figure with matplotlib

#Class 1
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

# %%
np.random.seed(613) #613 random number
x = np.arange(50) #range size from 1 to 50
y = np.random. randint(0,100,50) #（min,max, #generate numer)

# %%
fig, ax = plt.subplots(figsize=(5,3))  #figsize can be adjustment once have more data, 5 inch and 3 inch
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.bar(x,y) # differtn graph type
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y) # differtn graph type
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

# %%
ax.set_title('Total growht over time')
ax.set_ylabel('Total Growth')
ax.set_xlabel('Years since start')

font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

# %%
ax.set_title('Total growht over time',fontdict=font1)
ax.set_ylabel('Total Growth',fontdict=font2)
ax.set_xlabel('Years since start',fontdict=font2)


fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker= '*',
           color ='indigo', # can have HEX code
           linestyle = '--',
           linewidth = 2,
           markeredgecolor='#FA9359',
           markerfacecolor= '#000000')

ax.grid(axis='y',color = 'dodgerblue') #add grid lines to axis object

# %%
#Class 2 ( reproducibility)
#Reproducible work is "capable of being checked beacuse the data, code, and methods of analysis are avaiable to other researchers"

#Activity: comments code
# Creating a subplot with specific figure size
fig, ax = plt.subplots(figsize=(5,3))

# Plotting data with custom style
ax.plot(x, y,
        marker='*',              # Star-shaped markers
        color='indigo',          # Line color
        linestyle='--',          # Dashed line
        linewidth=2,             # Line width
        markeredgecolor='#FA9359',  # Marker edge color
        markerfacecolor='#000000')   # Marker face color

# Adding a grid only to the y-axis
ax.grid(axis='y', color='dodgerblue')

# %% [markdown]
# #good comment
# # Be Clear and Concise: Comments should be easy to read and to the point. Avoid unnecessary jargon or overly technical language.
# # Explain the 'Why': Rather than stating what the code does (which should be clear from the code itself), explain why it's doing it.
# # Avoid Redundancy: Don't state the obvious. If the code is self-explanatory, there's no need for a comment.
#
# #how is our data visualization perceived? notes and comments as below
# # Clarity: Is the data visualization easy to understand at a glance? Avoid clutter and ensure the most important information stands out.
#
# # Accuracy: Are the data points correctly represented? It's crucial that the visualization accurately reflects the underlying data.
#
# # Relevance: Does the visualization provide relevant insights? Make sure it addresses the questions or objectives at hand.
#
# # Design: Are the colors, fonts, and styles chosen appropriately? Good design enhances readability and engagement without being distracting.
#
# # Context: Is there enough context provided to understand the visualization? Labels, legends, and annotations can help explain the data.
#
# # Engagement: Is the visualization interesting and engaging? While being informative, it should also capture the viewer's attention.

# %%
#Class 3 , Customizing our plots

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

# %%
np.random.seed(613)
x = np. arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1,label="Person 1")
ax.plot(x,y2,label="Person 2")
ax.legend(loc = "lower right",
          frameon = True,
          fontsize = 12,
          ncol = 2,
          shadow = True)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1,label="Person 1")
ax.plot(x,y2,label="Person 2")
ax.legend(loc = "upper left", # change location to "lower/ upper right/left"
          bbox_to_anchor = (1,1))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")
ax.text (10,95, "This value is important!",
         ha="center",
         color = "red",
         size = 20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig,ax = plt.subplots()
ax.axis([0,10,0,10])
ax.text (1,5, ".  Data : (1,5)", transform = ax.transData)
ax.text (0.5,0.1, ". Axes : (0.5,0.1)", transform = ax.transAxes)
ax.text (0.2,0.2, ". Figure : (0.2,0.2)", transform = fig.transFigure)
# Out:
# Text(0.2, 0.2, '. Figure : (0.2,0.2)')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1,label="Person 1")
ax.plot(x,y2,label="Person 2")
ax.legend(loc = "lower right")

ax.annotate("This is important!", xy= (10,95),
            xytext =(20,94),
            arrowprops=dict(facecolor='hotpink',arrowstyle='wedge'))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")

ax.yaxis.set_major_locator(plt.NullLocator()) #locator to remove ticks and lables
ax.xaxis.set_major_formatter(plt.NullFormatter()) #formatter to remove only lables

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")
#ax.xaxis.set_major_locator(plt.MMaxNLocator(3))
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.xticks(rotation =45,
           ha= "right",
           fontsize =12,
           font = "serif")
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50., 55.]),
#  [Text(-5.0, 0, '−5'),
#   Text(0.0, 0, '0'),
#   Text(5.0, 0, '5'),
#   Text(10.0, 0, '10'),
#   Text(15.0, 0, '15'),
#   Text(20.0, 0, '20'),
#   Text(25.0, 0, '25'),
#   Text(30.0, 0, '30'),
#   Text(35.0, 0, '35'),
#   Text(40.0, 0, '40'),
#   Text(45.0, 0, '45'),
#   Text(50.0, 0, '50'),
#   Text(55.0, 0, '55')])

# %%
plt.xlabel("Shiny New X axis!", fontsize=18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiny New X axis!')

# %%
plt.xlabel("Shiny New X axis!", fontsize=18, fontdict = font1)
plt.style.use('dark_background')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array (["Luffy","Zoro","Nami","Usopp","Sanji"])
y2 = np.array ([110,180,240,99,220])

fig, (ax1,ax2) = plt.subplots (ncols=2,
    nrows=1,
    figsize=(7,3))
ax1.scatter (x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, (ax1,ax2) = plt.subplots (ncols=2, nrows=1, figsize=(9,3))
font1 = {'family':'serif','size':10}
font2 = {'family':'serif','size':14}

ax1.scatter (x1,y1,marker='o', color='darkred')
ax2.bar(x2,y2,color='darkblue')
# Out:
# <BarContainer object of 5 artists>

# %%
ax1.set_title('Important Scatterplot', fontdict=font2)
ax1.set_ylabel('measure',fontdict=font1)
ax1.set_xlabel('Time',fontdict=font1)
# Out:
# Text(0.5, 4.444444444444445, 'Time')

# %%
fig, someaxes=plt.subplot_mosaic([['ax1','ax3'],
                                 ['ax2','ax3']],
                                 figsize=(7,4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

# %%
fig, someaxes=plt.subplot_mosaic([['ax1','ax3'],
                                 ['ax2','ax3']],
                                 figsize=(7,4),
                                 layout="constrained")
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel("A Big Label", fontsize = 18)
someaxes["ax2"].set_xlabel("Another Label", fontsize = 18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious", fontsize = 18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')
